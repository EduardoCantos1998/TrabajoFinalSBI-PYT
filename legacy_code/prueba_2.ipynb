# %%
import pickle
import pandas as pd

# %%
with open("dictionary.pckl", "rb") as file:
    df_dict = pickle.load(file)

# %%
len(df_dict.keys())
# Out:
# 616

# %%
for i in df_dict.keys():
    print(i)
    print(df_dict[i].BINDING_ATOM.unique())
# Out:
# 1uog_1
# [0 1]
# 1tkg_1
# [0 1]
# 3vil_1
# [0 1]
# 3i81_1
# [0 1]
# 4weq_1
# [0 1]
# 2eg2_1
# [0 1]
# 4iil_1
# [0 1]
# 4jrn_1
# [0 1]
# 4ep6_1
# [0 1]
# 2gsq_1
# [0 1]
# 2xrh_1
# [0 1]
# 2f7z_1
# [0 1]
# 3gwf_2
# [0 1]
# 3ket_1
# [0 1]
# 3f3s_2
# [0 1]
# 3ts1_1
# [0 1]
# 3vqu_1
# [0 1]
# 3u2l_1
# [0 1]
# 2wot_1
# [0 1]
# 4dlc_1
# [0 1]
# 4gue_1
# [0 1]
# 2cf6_1
# [0 1]
# 4oau_1
# [0 1]
# 3ocs_1
# [0 1]
# 5fwn_1
# [0 1]
# 2xtb_1
# [0 1]
# 3bqr_1
# [0 1]
# 2j0j_1
# [0 1]
# 1bdb_1
# [0 1]
# 4cnf_1
# [0 1]
# 1qap_1
# [0 1]
# 3nv6_1
# [0 1]
# 3u3o_2
# [0 1]
# 5c7t_1
# [0 1]
# 2ixa_1
# [0 1]
# 1jhv_1
# [0 1]
# 3dt2_1
# [0 1]
# 4fr0_1
# [0 1]
# 4n6h_1
# [0 1]
# 4u15_2
# [0 1]
# 2yd0_1
# [0 1]
# 4psb_1
# [0 1]
# 2xtk_1
# [0 1]
# 1hqp_1
# [0 1]
# 4b4d_1
# [0 1]
# 2xj9_1
# [0 1]
# 4ntd_1
# [0 1]
# 4fh5_1
# [0 1]
# 3tq8_1
# [0 1]
# 4jv6_1
# [0 1]
# 4v12_1
# [0 1]
# 4i8z_1
# [0 1]
# 3baz_1
# [0 1]
# 3nf4_1
# [0 1]
# 3qfz_2
# [0 1]
# 2os3_1
# [0 1]
# 4i1c_1
# [0 1]
# 4ehy_1
# [0 1]
# 2bjf_1
# [1 0]
# 4koa_1
# [0 1]
# 4e2b_1
# [0 1]
# 2vq3_2
# [0 1]
# 1a27_1
# [0 1]
# 4yqf_1
# [0 1]
# 3qp6_1
# [0 1]
# 1z4u_1
# [0 1]
# 4ocv_1
# [0 1]
# 4la1_1
# [0 1]
# 4e1z_1
# [0 1]
# 4m81_1
# [0 1]
# 5dbv_1
# [0 1]
# 2cej_1
# [0 1]
# 2ewb_1
# [0 1]
# 2cbj_2
# [0 1]
# 4ir5_1
# [0 1]
# 1re0_1
# [0 1]
# 3fpb_2
# [0 1]
# 3ei8_2
# [0 1]
# 4y9d_1
# [0 1]
# 2ieo_1
# [0 1]
# 5eqb_1
# [0 1]
# 4hut_2
# [0 1]
# 1pkf_1
# [0 1]
# 4uco_1
# [0 1]
# 4dyd_1
# [0 1]
# 1zp8_1
# [0 1]
# 3dsr_1
# [0 1]
# 1o69_1
# [0 1]
# 2w0x_1
# [0 1]
# 3kh5_2
# [0 1]
# 1lox_1
# [0 1]
# 4ira_1
# [0 1]
# [0 1]
# 1gwj_1
# [0 1]
# 3sa7_1
# [0 1]
# 4qvb_1
# [0 1]
# 3ecg_1
# [0 1]
# 4d8n_1
# [0 1]
# 3b6z_1
# [0 1]
# 3p7n_2
# [1 0]
# 3zei_1
# [0 1]
# 1vhz_1
# [0 1]
# 2r7p_1
# [0 1]
# 2z3u_1
# [0 1]
# 3te4_1
# [0 1]
# 4epq_1
# [0 1]
# 1t32_1
# [0 1]
# 3hk1_1
# [0 1]
# 2z7q_1
# [0 1]
# 1pjc_1
# [0 1]
# 3ktl_1
# [0 1]
# 3tfu_2
# [0 1]

# %%
import math

nan_list = []
for i in df_dict.keys():
    for j in df_dict[i]:
        for k in df_dict[i][j]:
            if math.isnan(k):
                nan_list.append(i)
print(len(set(nan_list)))
# Out:
# 0

# %%
for i in df_dict.keys():
    for j in df_dict[i]:
        for index, k in enumerate(df_dict[i][j]):
            if math.isnan(k):
                df_dict[i][j][index] = 7
# Out:
# /tmp/ipykernel_6327/1938446440.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dict[i][j][index] = 7

# %%
    amino_keys = {
    'ALA': 0, 'ARG': 1, 'ASN': 2, 'ASP': 3, 'CYS': 4, 'GLN': 5, 'GLU': 6, 'GLY': 7, 
    'HIS': 8, 'ILE': 9, 'LEU': 10, 'LYS': 11, 'MET': 12, 'PHE': 13, 'PRO': 14, 
    'SER': 15, 'THR': 16, 'TRP': 17, 'TYR': 18, 'VAL': 19
    }
    SS_dict = {'-': 0, 'B': 1, 'T': 2, 'S': 3, 'G': 4, 'E': 5, 'H': 6, 'I': 7}
    
    def flipper(X):
        new_X = {}
        for i in X.keys():
            new_X[X[i]] = i
        return new_X 

    new_amino_keys = flipper(amino_keys)
    new_SS = flipper(SS_dict)

    print(new_amino_keys)
    print(new_SS)

# %%
import pickle

with open("dictionary.pckl", "wb") as file:
    pickle.dump(df_dict,file)

# %%
df_dict['2eg2_1']
# Out:
#     X_COORD  Y_COORD    Z_COORD  PROTEIN_AVG_LENGTH  BINDING_ATOM  \
# 0    -0.872   10.905  13.102000           17.454081             0
# 1     1.943   13.023  11.671000           15.926132             0
# 2     5.042   14.751  13.013000           14.661764             0
# 3     5.374   18.333  11.839000           13.677184             0
# 4     9.027   19.475  11.976000           13.784837             0
# ..      ...      ...        ...                 ...           ...
# 90   -2.550    6.784  19.593000           20.655528             0
# 91   -5.550    9.063  19.792000           20.673634             0
# 92   -5.438    8.821  23.577000           21.799729             0
# 93   -1.810   10.002  23.740999           19.735078             0
# 94   -1.954   13.122  21.556999           17.629183             0
#
#     PROTEIN_PSI  PROTEIN_PHI  AA  CHARGES           SASA  SECONDARY_STRUCTURE  \
# 0      0.000000     0.000000  12        0 -443482.456414                    0
# 1      0.283444     1.030883  11        1 -440562.069572                    5
# 2      0.824112     0.147069  11        1 -438086.982072                    5
# 3      1.442595     1.793828   9        0 -435832.015625                    5
# 4      0.484492     0.267214   6       -1 -433130.040954                    5
# ..          ...          ...  ..      ...            ...                  ...
# 90     2.169939     3.277796   7        0  -17817.906528                    4
# 91     0.991473     2.439162   6       -1  -11367.905198                    4
# 92    -1.180298    -2.637801   5        0   -3513.793755                    4
# 93     0.924932     0.271748   0        0    1217.624140                    2
# 94     0.000000     0.000000   9        0    4731.240354                    0
#
#      B-FACTOR  HIDROPHOBICITY   ENTROPY
# 0   23.800000             1.9  0.117260
# 1   13.765556            -3.9  0.360154
# 2   13.656667            -3.9  0.360154
# 3   12.675000             4.5  0.392657
# 4   15.721111            -3.5  0.360154
# ..        ...             ...       ...
# 90  17.807500            -0.4  0.322099
# 91  29.797778            -3.5  0.360154
# 92  23.376667            -3.5  0.117260
# 93  19.976000             1.8  0.192415
# 94  36.985556             4.5  0.392657
#
# [95 rows x 14 columns]

# %%
unique_SS = df_dict["1i06_1"].SECONDARY_STRUCTURE.unique().tolist()
SS_dict = {}
for i, value in enumerate(unique_SS):
    SS_dict[value] = i
SS_dict
# Out:
# {'-': 0, 'B': 1, 'T': 2, 'S': 3, 'G': 4, 'E': 5, 'H': 6}

# %%
df_dict["1i06_1"].SECONDARY_STRUCTURE = df_dict["1i06_1"].SECONDARY_STRUCTURE.map(SS_dict)

# %%
mean = []
for i in df_dict["1i06_1"].SASA:
    mean.append(sum(i)/len(i))
df_dict["1i06_1"].SASA = mean

# %%
df_dict["1i06_1"]
# Out:
#        X_COORD    Y_COORD    Z_COORD  PROTEIN_AVG_LENGTH  BINDING_ATOM  \
# 0     1.944000  21.733000  36.964001           23.120471             0
# 1     3.908000  19.275999  34.827999           20.832855             0
# 2     5.222000  19.872999  31.341000           19.838115             0
# 3     7.387000  18.486000  28.538000           18.550880             0
# 4     9.734000  20.705999  26.483000           18.072795             0
# ..         ...        ...        ...                 ...           ...
# 151  22.431999  12.297000  45.582001           18.769352             0
# 152  25.257999  11.694000  48.105999           21.062856             0
# 153  27.997999  12.608000  45.613998           20.042203             0
# 154  26.565001  15.756000  44.148998           18.490604             0
# 155  28.041000  18.445999  46.411999           20.583832             0
#
#      PROTEIN_PSI  PROTEIN_PHI   AA  CHARGES           SASA  \
# 0       0.000000     0.000000  GLU     -1.0 -801362.046875
# 1       0.281914    -0.299915  GLU     -1.0 -796517.135216
# 2       1.254962     1.604822  ALA      0.0 -791392.711138
# 3      -0.003227     0.258735  SER      0.0 -787160.038061
# 4       1.639560     1.324141  SER      0.0 -782667.893830
# ..           ...          ...  ...      ...            ...
# 151     1.632070     1.543262  SER      0.0  -17890.981817
# 152     0.501629    -0.928187  ASN      0.0  -10348.496462
# 153     0.722616     1.033822  ALA      0.0   -5154.349481
# 154     1.362499     2.398621  ASN      0.0   -1095.535015
# 155     0.000000     0.000000  ARG      1.0    5998.679583
#
#      SECONDARY_STRUCTURE   B-FACTOR  HIDROPHOBICITY   ENTROPY
# 0                      0  45.956000            -3.5  0.379933
# 1                      0  42.115556            -3.5  0.379933
# 2                      1  33.718000             1.8  0.200938
# 3                      0  33.228333            -0.8  0.254069
# 4                      2  29.975000            -0.8  0.254069
# ..                   ...        ...             ...       ...
# 151                    2  32.918333            -0.8  0.254069
# 152                    2  42.032000            -3.5  0.284649
# 153                    2  41.314000             1.8  0.200938
# 154                    0  38.948750            -3.5  0.284649
# 155                    0  62.171818            -4.5  0.219764
#
# [156 rows x 14 columns]
